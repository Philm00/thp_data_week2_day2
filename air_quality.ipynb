# %%
import pandas as pd

# %%
df = pd.read_csv('openaq.csv',sep=";")

# %%
df['Last Updated']=df['Last Updated'].str[:10]

# %%
df= df[df['Last Updated'].str.contains('2021-08-06')]

# %%
df.head(60)
# Out:
#     Country Code                     City        Location  \
# 2             ES        Valencia/València         ES1885A
# 3             ES         Alicante/Alacant         ES2008A
# 4             ES         Alicante/Alacant         ES1968A
# 5             ES        Valencia/València         ES1911A
# 6             ES        Valencia/València         ES1185A
# 7             ES         Alicante/Alacant         ES1849A
# 8             ES                  Almería         ES1835A
# 9             ES                   Málaga         ES1750A
# 10            ES                  Sevilla         ES1654A
# 11            ES                    Cádiz         ES1076A
# 12            ES                   Huelva         ES1658A
# 13            ES                   Huelva         ES1878A
# 14            ES                   Huelva         ES1793A
# 15            ES                   Huelva         ES0787A
# 16            ES                   Madrid         ES1802A
# ...

# %%
df.head(60)
# Out:
#     Country Code                     City        Location  \
# 2             ES        Valencia/València         ES1885A
# 3             ES         Alicante/Alacant         ES2008A
# 4             ES         Alicante/Alacant         ES1968A
# 5             ES        Valencia/València         ES1911A
# 6             ES        Valencia/València         ES1185A
# 7             ES         Alicante/Alacant         ES1849A
# 8             ES                  Almería         ES1835A
# 9             ES                   Málaga         ES1750A
# 10            ES                  Sevilla         ES1654A
# 11            ES                    Cádiz         ES1076A
# 12            ES                   Huelva         ES1658A
# 13            ES                   Huelva         ES1878A
# 14            ES                   Huelva         ES1793A
# 15            ES                   Huelva         ES0787A
# 16            ES                   Madrid         ES1802A
# ...

# %%
pd.crosstab(df["City"],df["Pollutant"])
# Out:
# Pollutant    BC  CO  NO2  O3  PM10  PM2.5  SO2
# City
# 037           0   0    0   0     0      3    0
# ADA           0   0    0   0     0      1    0
# ADAIR         0   1    0   1     1      1    1
# ADAMS         0   0    0   0     1      2    0
# ALAMEDA       1   1    1   1     0      1    0
# ...          ..  ..  ...  ..   ...    ...  ...
# 黔东南苗族侗族自治州    0   2    2   2     2      2    2
# 黔南布依族苗族自治州    0   2    2   2     2      2    2
# 黔西南布依族苗族自治州   0   2    2   2     2      2    2
# 齐齐哈尔市         0   5    5   5     5      5    5
# 龙岩市           0   4    4   4     4      4    4
#
# [2219 rows x 7 columns]

# %%
df.drop_duplicates('City','Pollutant', keep='first')
# Out:
# /tmp/ipykernel_3706/1903202315.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop_duplicates except for the argument 'subset' will be keyword-only.
#   df.drop_duplicates('City','Pollutant', keep='first')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 df.drop_duplicates('City','Pollutant', keep='first')
#
# File ~/.local/lib/python3.8/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# TypeError: drop_duplicates() got multiple values for argument 'keep'

# %%
df.groupby('City')['Value'].nlargest()
# Out:
# City
# 037    2198       2.1
#        4317       2.1
#        34832      2.1
# ADA    33204     14.0
# ADAIR  8345      16.0
#                 ...
# 龙岩市    9810     700.0
#        1939     600.0
#        17964    500.0
#        30112    500.0
#        38805     78.0
# Name: Value, Length: 8031, dtype: float64

# %%
df.groupby('City', group_keys=False).apply(lambda x: x.loc[x.Value.idxmax()])
# Out:
#             Country Code         City              Location  \
# City
# 037                   US          037       Cle Elum_Mobile
# ADA                   US          ADA           Garden City
# ADAIR                 US        ADAIR  STILWELL CASTNET & N
# ADAMS                 US        ADAMS           Adams-Birch
# ALAMEDA               US      ALAMEDA  Berkeley Aquatic Par
# ...                  ...          ...                   ...
# 黔东南苗族侗族自治州            CN   黔东南苗族侗族自治州                  凯里学院
# 黔南布依族苗族自治州            CN   黔南布依族苗族自治州                    沙坝
# 黔西南布依族苗族自治州           CN  黔西南布依族苗族自治州                   场坝街
# 齐齐哈尔市                 CN        齐齐哈尔市                  中心广场
# 龙岩市                   CN          龙岩市              闽西职业技术学院
#
#                        Coordinates Pollutant   Source Name   Unit   Value  \
# City
# 037          47.197523,-120.958207     PM2.5        AirNow  µg/m³     2.1
# ADA          43.647888,-116.269409     PM2.5        AirNow  µg/m³    14.0
# ...
